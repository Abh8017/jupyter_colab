# %% [markdown]
# In this Data Visualisation part, we will explore Scatter plot, bar chart, line chart and Histogram

# %% [markdown]
# # Scatter Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x =np.random.randint(100,500,50)

# %%
y =np.random.randint(100,1000,50)
y1 =np.random.randint(100,1000,50)

# %%
x
# Out:
# array([256, 458, 118, 298, 124, 448, 229, 135, 167, 491, 212, 252, 322,
#        293, 200, 139, 201, 406, 110, 247, 451, 283, 277, 299, 203, 109,
#        356, 153, 279, 125, 460, 463, 161, 132, 159, 207, 292, 279, 245,
#        221, 115, 104, 177, 164, 166, 430, 460, 307, 195, 387])

# %%
y1
# Out:
# array([907, 347, 934, 748, 519, 774, 773, 639, 786, 252, 119, 939, 138,
#        585, 808, 591, 372, 919, 226, 943, 743, 962, 517, 894, 762, 283,
#        349, 455, 372, 747, 435, 783, 246, 348, 456, 751, 269, 871, 812,
#        745, 171, 369, 156, 309, 618, 312, 305, 992, 764, 665])

# %%
plt.scatter(x,y,marker = "s",color ="red")
plt.title ("Sample Scatter Plot with Random number")
plt.xlabel("X Axis Label")
plt.ylabel("Y Axis Label")

plt.show()

# %%
plt.scatter(x,y,marker = "s",color ="red")
plt.scatter(x,y1,marker = "^",color ="blue")
plt.title ("Sample Scatter Plot with Random number")
plt.xlabel("X Axis Label")
plt.ylabel("Y Axis Label")

plt.show()

# %% [markdown]
# # Bar Plot

# %%
x =np.arange(5)

# %%
y =np.random.randint(50,100,5)
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
xlist = list("ABCDE")

# %%
xlist
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
plt.bar(xlist,y)
# Out:
# <BarContainer object of 5 artists>

# %%
xlist = ["eng","science","maths","economics","geography"]

# %%
xlist
# Out:
# ['eng', 'science', 'maths', 'economics', 'geography']

# %%
plt.bar(xlist,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(xlist,y,color ="purple",bottom=x)
plt.title ("Subject Marks")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
y
# Out:
# array([94, 83, 90, 53, 99])

# %%
y1
# Out:
# array([907, 347, 934, 748, 519, 774, 773, 639, 786, 252, 119, 939, 138,
#        585, 808, 591, 372, 919, 226, 943, 743, 962, 517, 894, 762, 283,
#        349, 455, 372, 747, 435, 783, 246, 348, 456, 751, 269, 871, 812,
#        745, 171, 369, 156, 309, 618, 312, 305, 992, 764, 665])

# %%
xlist
# Out:
# ['eng', 'science', 'maths', 'economics', 'geography']

# %%
y1 =np.random.randint(50,100,5)

# %%
plt.bar(xlist,y,color = "green")
plt.bar(xlist,y,color ="blue",bottom=y1)
plt.title ("Subject Marks")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# # Line Chart

# %%
x = np.arange(1,7,1)

# %%
x
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
y= np.random.randint(50,100,6)

# %%
plt.plot(x,y)

# %%
xlist = ["sem 1","sem 2","sem 3","sem 4","sem 5","sem 6"]

# %%
plt.plot(xlist,y)

# %%
plt.plot(xlist,y)
plt.title("Overall College Performance")
plt.xlabel("Semester")
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %%
plt.plot(xlist,y,color ="redL")
plt.title("Overall College Performance")
plt.xlabel("Semester")
plt.ylabel("Percentage")
plt.plot(xlist,y,"b*")

# %% [markdown]
# # Histogram

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/abhijis2/Documents/HR_comma_sep.csv")

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %%
plt.hist(df["satisfaction_level"],bins=10)
# Out:
# (array([1335.,  498.,  477., 1778., 1471., 1775., 1768., 2115., 1998.,
#         1784.]),
#  array([0.09 , 0.181, 0.272, 0.363, 0.454, 0.545, 0.636, 0.727, 0.818,
#         0.909, 1.   ]),
#  <a list of 10 Patch objects>)
